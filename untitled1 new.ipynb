# %%
#Step -1
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandasql as psql

# Set to display all the columns of the dataset
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",500)

#Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Step -2
#Load the data
hsdata = pd.read_csv("train.csv")
#Step -3
#Copy to back_up file
hsdata_bk = hsdata.copy()
#Display first 5 records
hsdata.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Step -2
#       2 #Load the data
# ----> 3 hsdata = pd.read_csv("train.csv")
#       4 #Step -3
#       5 #Copy to back_up file
#       6 hsdata_bk = hsdata.copy()
#
# NameError: name 'pd' is not defined

# %%
#Step -4
#Display the data set information
hsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
#Step -5
# Checking for any duplicate values
hsdata_dup = hsdata[hsdata.duplicated(keep='last')]
hsdata_dup
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
# Description of categorical varibles

hsdata.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# top        Gable  CompShg     VinylSd     VinylSd       None        TA
# freq        1141     1434         515         504        864       906
#
#        ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# count       1460       1460     1423     1423         1422         1423
# unique         5          6        4        4            4            6
# top           TA      PConc       TA       TA           No          Unf
# freq        1282        647      649     1311          953          430
#
#        BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# count          1422    1460      1460       1460       1459        1460
# unique            6       6         5          2          5           4
# top             Unf    GasA        Ex          Y      SBrkr          TA
# freq           1256    1428       741       1365       1334         735
#
#        Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# count        1460         770       1379         1379       1379       1379
# unique          7           5          6            3          5          5
# top           Typ          Gd     Attchd          Unf         TA         TA
# freq         1360         380        870          605       1311       1326
#
#        PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# count        1460      7    281          54     1460          1460
# unique          3      3      4           4        9             6
# top             Y     Gd  MnPrv        Shed       WD        Normal
# freq         1340      3    157          49     1267          1198

# %%
# Description of numerical varibles

hsdata.describe(exclude="object")
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
# display the random sample of dataset 

hsdata.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 152    153          60       RL          NaN    14803   Pave   NaN      IR1
# 1186  1187         190       RL        107.0    10615   Pave   NaN      IR1
# 914    915         160       FV         30.0     3000   Pave  Pave      Reg
# 958    959          20       RL         65.0     8450   Pave   NaN      Reg
# 791    792          80       RL          NaN    11333   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 152          Lvl    AllPub   CulDSac       Gtl       NWAmes       Norm
# 1186         Bnk    AllPub    Corner       Mod      OldTown     Artery
# 914          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 958          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 791          Lvl    AllPub    Corner       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 152        Norm     1Fam     2Story            6            5       1971
# 1186     Artery   2fmCon     2Story            3            5       1900
# 914        Norm   TwnhsE     2Story            6            5       2009
# 958        Norm     1Fam     1Story            7            5       2003
# 791        Norm     1Fam       SLvl            6            5       1976
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 152           1971     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1186          1970     Gable  CompShg     HdBoard     HdBoard       None
# 914           2009     Gable  CompShg     VinylSd     VinylSd      Stone
# 958           2003     Gable  CompShg     VinylSd     VinylSd       None
# 791           1976     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 152        252.0        TA        TA     CBlock       TA       TA
# 1186         0.0        TA        TA     CBlock       Fa       TA
# 914         76.0        Gd        TA      PConc       Gd       TA
# 958          0.0        Gd        TA      PConc       Gd       TA
# 791          0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 152            No          Rec         416          Unf           0
# 1186           Mn          BLQ         440          Unf           0
# 914            Av          GLQ         294          Unf           0
# 958            Mn          GLQ         699          Unf           0
# 791            Av          ALQ         539          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 152         409          825    GasA        Gd          Y      SBrkr
# 1186        538          978    GasA        TA          Y      SBrkr
# 914         318          612    GasA        Ex          Y      SBrkr
# 958         638         1337    GasA        Ex          Y      SBrkr
# 791         490         1029    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 152       1097       896             0       1993             0             0
# 1186      1014       685             0       1699             1             0
# 914        612       612             0       1224             0             0
# 958       1337         0             0       1337             1             0
# 791       1062         0             0       1062             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 152          2         1             4             1          TA
# 1186         2         0             3             2          TA
# 914          2         1             2             1          Gd
# 958          2         0             3             1          Gd
# 791          1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 152              8        Typ           1          Gd     Attchd       1971.0
# 1186             7        Typ           0         NaN    CarPort       1920.0
# 914              4        Typ           0         NaN     Detchd       2009.0
# 958              6        Typ           0         NaN     Attchd       2003.0
# 791              5        Typ           2          TA     Attchd       1976.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 152           RFn           2         495         TA         TA          Y
# 1186          Unf           2         420         Fa         Fa          Y
# 914           RFn           2         528         TA         TA          Y
# 958           RFn           2         531         TA         TA          Y
# 791           RFn           2         539         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 152            0           66              0          0            0
# 1186           0           74              0          0            0
# 914            0          234              0          0            0
# 958            0           39              0          0            0
# 791          120            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 152          0    NaN  GdWo         NaN        0       6    2006       WD
# 1186         0    NaN   NaN         NaN        0       8    2009       WD
# 914          0    NaN   NaN         NaN        0       6    2009      New
# 958          0    NaN   NaN         NaN        0      10    2007       WD
# 791          0    NaN   NaN         NaN        0       5    2007       WD
#
#      SaleCondition  SalePrice
# 152         Normal     190000
# 1186       Abnorml      95000
# 914        Partial     173733
# 958         Normal     185000
# 791         Normal     146800

# %%
# deleting id which doesn't effect Target Variable SalePrice

hsdata = hsdata.drop(["Id"],axis=1)

# %%
# display the first five rows of dataset

hsdata.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
#step-6
# Checking if there are any null values
hsdata.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
# Calculating the percentage of null values

percent_null = round(hsdata.isnull().sum()/len(hsdata) *100,2)
percent_null = pd.DataFrame(percent_null,columns=['% null values'])
percent_null[percent_null['% null values']>0]
# Out:
#               % null values
# LotFrontage           17.74
# Alley                 93.77
# MasVnrType             0.55
# MasVnrArea             0.55
# BsmtQual               2.53
# BsmtCond               2.53
# BsmtExposure           2.60
# BsmtFinType1           2.53
# BsmtFinType2           2.60
# Electrical             0.07
# FireplaceQu           47.26
# GarageType             5.55
# GarageYrBlt            5.55
# GarageFinish           5.55
# GarageQual             5.55
# GarageCond             5.55
# PoolQC                99.52
# Fence                 80.75
# MiscFeature           96.30

# %%
# display the variables with more than 45 % of null values

percent_null[percent_null['% null values'] > 45]
# Out:
#              % null values
# Alley                93.77
# FireplaceQu          47.26
# PoolQC               99.52
# Fence                80.75
# MiscFeature          96.30

# %% [markdown]
# the above features have a very large number of missing values. So we drop them

# %%
# dropping the columns

hsdata = hsdata.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'],axis = 1)
hsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
#  18  YearRemodAdd   1460 non-null   int64
#  19  RoofStyle      1460 non-null   object
#  20  RoofMatl       1460 non-null   object
#  21  Exterior1st    1460 non-null   object
#  22  Exterior2nd    1460 non-null   object
#  23  MasVnrType     1452 non-null   object
#  24  MasVnrArea     1452 non-null   float64
#  25  ExterQual      1460 non-null   object
#  26  ExterCond      1460 non-null   object
#  27  Foundation     1460 non-null   object
#  28  BsmtQual       1423 non-null   object
#  29  BsmtCond       1423 non-null   object
#  30  BsmtExposure   1422 non-null   object
#  31  BsmtFinType1   1423 non-null   object
#  32  BsmtFinSF1     1460 non-null   int64
#  33  BsmtFinType2   1422 non-null   object
#  34  BsmtFinSF2     1460 non-null   int64
#  35  BsmtUnfSF      1460 non-null   int64
#  36  TotalBsmtSF    1460 non-null   int64
#  37  Heating        1460 non-null   object
#  38  HeatingQC      1460 non-null   object
#  39  CentralAir     1460 non-null   object
#  40  Electrical     1459 non-null   object
#  41  1stFlrSF       1460 non-null   int64
#  42  2ndFlrSF       1460 non-null   int64
#  43  LowQualFinSF   1460 non-null   int64
#  44  GrLivArea      1460 non-null   int64
#  45  BsmtFullBath   1460 non-null   int64
#  46  BsmtHalfBath   1460 non-null   int64
#  47  FullBath       1460 non-null   int64
#  48  HalfBath       1460 non-null   int64
#  49  BedroomAbvGr   1460 non-null   int64
#  50  KitchenAbvGr   1460 non-null   int64
#  51  KitchenQual    1460 non-null   object
#  52  TotRmsAbvGrd   1460 non-null   int64
#  53  Functional     1460 non-null   object
#  54  Fireplaces     1460 non-null   int64
#  55  GarageType     1379 non-null   object
#  56  GarageYrBlt    1379 non-null   float64
#  57  GarageFinish   1379 non-null   object
#  58  GarageCars     1460 non-null   int64
#  59  GarageArea     1460 non-null   int64
#  60  GarageQual     1379 non-null   object
#  61  GarageCond     1379 non-null   object
#  62  PavedDrive     1460 non-null   object
#  63  WoodDeckSF     1460 non-null   int64
#  64  OpenPorchSF    1460 non-null   int64
#  65  EnclosedPorch  1460 non-null   int64
#  66  3SsnPorch      1460 non-null   int64
#  67  ScreenPorch    1460 non-null   int64
#  68  PoolArea       1460 non-null   int64
#  69  MiscVal        1460 non-null   int64
#  70  MoSold         1460 non-null   int64
#  71  YrSold         1460 non-null   int64
#  72  SaleType       1460 non-null   object
#  73  SaleCondition  1460 non-null   object
#  74  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(38)
# memory usage: 855.6+ KB

# %%
# find % null values of remaining variables

percent_null2 = round(hsdata.isnull().sum()/len(hsdata) *100,2)
percent_null2 = pd.DataFrame(percent_null2,columns=['% null values'])
rem_null = percent_null2[percent_null2['% null values']>0]
rem_null
# Out:
#               % null values
# LotFrontage           17.74
# MasVnrType             0.55
# MasVnrArea             0.55
# BsmtQual               2.53
# BsmtCond               2.53
# BsmtExposure           2.60
# BsmtFinType1           2.53
# BsmtFinType2           2.60
# Electrical             0.07
# GarageType             5.55
# GarageYrBlt            5.55
# GarageFinish           5.55
# GarageQual             5.55
# GarageCond             5.55

# %% [markdown]
# still there are 29 columns with missing values

# %%
# identifying categorical and numerical variables

cat_vars = hsdata.columns[hsdata.dtypes == 'object']
num_vars = hsdata.columns[hsdata.dtypes != 'object']

# identifying categorical with null values
cat_vars = set(rem_null.index).intersection(cat_vars)

# identifying numerical with null values

num_vars = set(rem_null.index).intersection(num_vars)

# %% [markdown]
# filling categorical values with mode

# %%
for i in cat_vars:
    hsdata[i] = hsdata[i].fillna(hsdata[i].mode()[0])

# %% [markdown]
# filling numerical variables with mean

# %%
for i in num_vars:
    hsdata[i] = hsdata[i].fillna(hsdata[i].mean())

# %%
# confirming that there are no null values entirely

hsdata.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %% [markdown]
# Relationship between variables so that we can drop unnecessary ones

# %%
hsdata.corrwith(hsdata['SalePrice'])
# Out:
# MSSubClass      -0.084284
# LotFrontage      0.334901
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.475241
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.470177
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# YrSold          -0.028923
# SalePrice        1.000000
# dtype: float64

# %% [markdown]
# LowQualFinSF,MiscVal,BsmtFinSF2,PoolArea,3SsnPorch,ScreenPorch have very low correlation with the target variable so dropping them.

# %%
# dropping the columns
hsdata = hsdata.drop(['LowQualFinSF','MiscVal','BsmtFinSF2','PoolArea','3SsnPorch','ScreenPorch'],axis=1)

# %%
#step-7
#Outliers checking

# %%
# plotting histogram for the target variable.

sns.histplot(hsdata['SalePrice'],kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
# boxplot for checking outliers

sns.boxplot(hsdata['SalePrice'])
# Out:
# <Axes: >

# %%
# getting outliers

first_quantile=hsdata["SalePrice"].quantile(.25)
third_quantile=hsdata["SalePrice"].quantile(.75)
IQR=third_quantile - first_quantile

#getting upper and lower bounds

Upper_bound=round(third_quantile + 1.5 * IQR ,3) 
Lower_bound=round(third_quantile - 1.5 * IQR ,3)

# %%
#Eliminating the outliers

hsdata = hsdata[(hsdata.SalePrice > Lower_bound) & (hsdata.SalePrice < Upper_bound)]

# %%
sns.histplot(hsdata['SalePrice'],kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
#step-8,9
# Datatype conversion and encoding techinque

# %%
cat_vars = hsdata.columns[hsdata.dtypes == 'object']
num_vars = hsdata.columns[hsdata.dtypes != 'object'][:-1]

# %%
hsdata.describe(include="object")
# Out:
#        MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# count      1328   1328     1328        1328      1328      1328      1328
# unique        5      2        4           4         2         5         3
# top          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# freq       1063   1324      843        1203      1327       951      1260
#
#        Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# count          1328       1328       1328     1328       1328      1328
# unique           25          9          8        5          8         6
# top           NAmes       Norm       Norm     1Fam     1Story     Gable
# freq            223       1147       1317     1105        653      1058
#
#        RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# count      1328        1328        1328       1328      1328      1328
# unique        8          14          16          4         4         4
# top     CompShg     VinylSd     VinylSd       None        TA        TA
# freq       1306         470         459        796       841      1176
#
#        Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# count        1328     1328     1328         1328         1328         1328
# unique          6        4        3            4            6            6
# top        CBlock       TA       TA           No          Unf          Unf
# freq          594      629     1232          921          414         1170
#
#        Heating HeatingQC CentralAir Electrical KitchenQual Functional  \
# count     1328      1328       1328       1328        1328       1328
# unique       5         4          2          4           4          7
# top       GasA        Ex          Y      SBrkr          TA        Typ
# freq      1307       674       1266       1230         681       1239
#
#        GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# count        1328         1328       1328       1328       1328     1328
# unique          6            3          5          5          3        9
# top        Attchd          Unf         TA         TA          Y       WD
# freq          869          616       1271       1285       1238     1175
#
#        SaleCondition
# count           1328
# unique             6
# top           Normal
# freq            1117

# %%
# encoding the categorical variable One hot encoding

hsdata = pd.get_dummies(hsdata,columns=cat_vars)

# %%
hsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1328 entries, 0 to 1459
# Columns: 259 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(3), int64(28), uint8(228)
# memory usage: 627.7 KB

# %% [markdown]
# # defining independent and Target Variables

# %%
#step-10
IndepVar = []
for col in hsdata.columns:
    if col != 'SalePrice':
        IndepVar.append(col)
TargetVar = 'SalePrice'

x = hsdata[IndepVar]
y = hsdata[TargetVar]

# %% [markdown]
# # spliting the data into train and test data

# %%
#step-11
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# ((1062, 258), (266, 258), (1062,), (266,))

# %% [markdown]
# # Scaling technique for continuous variables using StandardScaler

# %%
#step-12
from sklearn.preprocessing import StandardScaler
mmscaler = StandardScaler()
x_train[num_vars] = mmscaler.fit_transform(x_train[num_vars])
x_train = pd.DataFrame(x_train)

x_test[num_vars] = mmscaler.fit_transform(x_test[num_vars])
x_test = pd.DataFrame(x_test)

# %% [markdown]
# # Model Building

# %% [markdown]
# KNN Algorithm

# %%
#step-13
KNN_Results = pd.read_csv(r"KNNResults.csv",header=0)

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

import sklearn.metrics as metrics

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsRegressor(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    MAE = round(metrics.mean_absolute_error(y_test, y_pred), 3)
    MSE = round(metrics.mean_squared_error(y_test, y_pred),3)
    RMSE = round (np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3)
    R2_score = round(metrics.r2_score (y_test, y_pred),6)
    MAPE = round(metrics.mean_absolute_percentage_error(y_test, y_pred)*100,3)
    RMSLE = round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3)
    Adj_R_Square = round(1 - (1-R2_score)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Mean Absolute Error (MAE):', MAE)
    print('Mean Squared Error (MSE):',MSE)
    print('Root Mean Squared Error (RMSE):', RMSE)
    print('R2_score:',R2_score)
    print('Mean Absolute Percentage Error (MAPE):',MAPE , '%')
    print('Root Mean Squared Log Error (RMSLE):',RMSLE)
    print('Adj R Square: ', Adj_R_Square)
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'Mean_Absolute_Error_MAE' : MAE,
               'Adj_R_Square' : Adj_R_Square,
               'Root_Mean_Squared_Error_RMSE' : RMSE,
               'Mean_Absolute_Percentage_Error_MAPE' : MAPE,
               'Mean_Squared_Error_MSE' : MSE,
               'Root_Mean_Squared_Log_Error_RMSLE' : RMSLE,
               'R2_score' : R2_score,
               }
    KNN_Results = KNN_Results.append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsRegressor(n_neighbors=1)
# Mean Absolute Error (MAE): 17689.398
# Mean Squared Error (MSE): 590423398.218
# Root Mean Squared Error (RMSE): 24298.63
# R2_score: 0.816135
# Mean Absolute Percentage Error (MAPE): 10.413 %
# Root Mean Squared Log Error (RMSLE): 10.098
# Adj R Square:  0.77176
# KNN_K_value =  2
# Model Name:  KNeighborsRegressor(n_neighbors=2)
# Mean Absolute Error (MAE): 15562.853
# Mean Squared Error (MSE): 462692150.741
# Root Mean Squared Error (RMSE): 21510.28
# R2_score: 0.855912
# Mean Absolute Percentage Error (MAPE): 8.966 %
# Root Mean Squared Log Error (RMSLE): 9.976
# Adj R Square:  0.821137
# KNN_K_value =  3
# Model Name:  KNeighborsRegressor(n_neighbors=3)
# Mean Absolute Error (MAE): 14716.791
# Mean Squared Error (MSE): 404161056.294
# Root Mean Squared Error (RMSE): 20103.757
# R2_score: 0.874139
# Mean Absolute Percentage Error (MAPE): 8.647 %
# Root Mean Squared Log Error (RMSLE): 9.909
# Adj R Square:  0.843763
# KNN_K_value =  4
# Model Name:  KNeighborsRegressor(n_neighbors=4)
# Mean Absolute Error (MAE): 14893.617
# Mean Squared Error (MSE): 415447876.423
# Root Mean Squared Error (RMSE): 20382.539
# R2_score: 0.870624
# Mean Absolute Percentage Error (MAPE): 8.702 %
# Root Mean Squared Log Error (RMSLE): 9.922
# Adj R Square:  0.839399
# KNN_K_value =  5
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 14573.07
# Mean Squared Error (MSE): 403420769.448
# Root Mean Squared Error (RMSE): 20085.337
# R2_score: 0.87437
# Mean Absolute Percentage Error (MAPE): 8.531 %
# Root Mean Squared Log Error (RMSLE): 9.908
# Adj R Square:  0.84405
# KNN_K_value =  6
# Model Name:  KNeighborsRegressor(n_neighbors=6)
# Mean Absolute Error (MAE): 14987.323
# Mean Squared Error (MSE): 415788447.932
# Root Mean Squared Error (RMSE): 20390.891
# R2_score: 0.870518
# Mean Absolute Percentage Error (MAPE): 8.726 %
# Root Mean Squared Log Error (RMSLE): 9.923
# Adj R Square:  0.839268
# KNN_K_value =  7
# Model Name:  KNeighborsRegressor(n_neighbors=7)
# Mean Absolute Error (MAE): 15127.345
# Mean Squared Error (MSE): 426336044.072
# Root Mean Squared Error (RMSE): 20647.907
# R2_score: 0.867234
# Mean Absolute Percentage Error (MAPE): 8.798 %
# Root Mean Squared Log Error (RMSLE): 9.935
# Adj R Square:  0.835191
# KNN_K_value =  8
# Model Name:  KNeighborsRegressor(n_neighbors=8)
# Mean Absolute Error (MAE): 15279.078
# Mean Squared Error (MSE): 438984429.845
# Root Mean Squared Error (RMSE): 20951.955
# R2_score: 0.863295
# Mean Absolute Percentage Error (MAPE): 8.881 %
# Root Mean Squared Log Error (RMSLE): 9.95
# Adj R Square:  0.830302
# KNN_K_value =  9
# Model Name:  KNeighborsRegressor(n_neighbors=9)
# Mean Absolute Error (MAE): 15407.455
# Mean Squared Error (MSE): 453713902.958
# Root Mean Squared Error (RMSE): 21300.561
# R2_score: 0.858708
# Mean Absolute Percentage Error (MAPE): 8.987 %
# Root Mean Squared Log Error (RMSLE): 9.966
# Adj R Square:  0.824608
# KNN_K_value =  10
# Model Name:  KNeighborsRegressor(n_neighbors=10)
# Mean Absolute Error (MAE): 15710.534
# Mean Squared Error (MSE): 471801036.252
# Root Mean Squared Error (RMSE): 21720.981
# R2_score: 0.853075
# Mean Absolute Percentage Error (MAPE): 9.161 %
# Root Mean Squared Log Error (RMSLE): 9.986
# Adj R Square:  0.817615
# KNN_K_value =  11
# Model Name:  KNeighborsRegressor(n_neighbors=11)
# Mean Absolute Error (MAE): 15765.444
# Mean Squared Error (MSE): 474165630.897
# Root Mean Squared Error (RMSE): 21775.345
# R2_score: 0.852339
# Mean Absolute Percentage Error (MAPE): 9.22 %
# Root Mean Squared Log Error (RMSLE): 9.989
# Adj R Square:  0.816701
# KNN_K_value =  12
# Model Name:  KNeighborsRegressor(n_neighbors=12)
# Mean Absolute Error (MAE): 15742.914
# Mean Squared Error (MSE): 478643278.802
# Root Mean Squared Error (RMSE): 21877.918
# R2_score: 0.850945
# Mean Absolute Percentage Error (MAPE): 9.179 %
# Root Mean Squared Log Error (RMSLE): 9.993
# Adj R Square:  0.814971
# KNN_K_value =  13
# Model Name:  KNeighborsRegressor(n_neighbors=13)
# Mean Absolute Error (MAE): 15864.173
# Mean Squared Error (MSE): 482560517.478
# Root Mean Squared Error (RMSE): 21967.26
# R2_score: 0.849725
# Mean Absolute Percentage Error (MAPE): 9.288 %
# Root Mean Squared Log Error (RMSLE): 9.997
# Adj R Square:  0.813457
# KNN_K_value =  14
# Model Name:  KNeighborsRegressor(n_neighbors=14)
# Mean Absolute Error (MAE): 16087.714
# Mean Squared Error (MSE): 498668179.366
# Root Mean Squared Error (RMSE): 22330.88
# R2_score: 0.844709
# Mean Absolute Percentage Error (MAPE): 9.389 %
# Root Mean Squared Log Error (RMSLE): 10.014
# Adj R Square:  0.80723
# KNN_K_value =  15
# Model Name:  KNeighborsRegressor(n_neighbors=15)
# Mean Absolute Error (MAE): 16301.763
# Mean Squared Error (MSE): 513758219.84
# Root Mean Squared Error (RMSE): 22666.235
# R2_score: 0.840009
# Mean Absolute Percentage Error (MAPE): 9.5 %
# Root Mean Squared Log Error (RMSLE): 10.029
# Adj R Square:  0.801396
# KNN_K_value =  16
# Model Name:  KNeighborsRegressor(n_neighbors=16)
# Mean Absolute Error (MAE): 16466.947
# Mean Squared Error (MSE): 527004207.168
# Root Mean Squared Error (RMSE): 22956.572
# R2_score: 0.835884
# Mean Absolute Percentage Error (MAPE): 9.578 %
# Root Mean Squared Log Error (RMSLE): 10.041
# Adj R Square:  0.796275
# KNN_K_value =  17
# Model Name:  KNeighborsRegressor(n_neighbors=17)
# Mean Absolute Error (MAE): 16650.276
# Mean Squared Error (MSE): 537281669.515
# Root Mean Squared Error (RMSE): 23179.337
# R2_score: 0.832684
# Mean Absolute Percentage Error (MAPE): 9.658 %
# Root Mean Squared Log Error (RMSLE): 10.051
# Adj R Square:  0.792303
# KNN_K_value =  18
# Model Name:  KNeighborsRegressor(n_neighbors=18)
# Mean Absolute Error (MAE): 16781.416
# Mean Squared Error (MSE): 544863040.386
# Root Mean Squared Error (RMSE): 23342.302
# R2_score: 0.830323
# Mean Absolute Percentage Error (MAPE): 9.752 %
# Root Mean Squared Log Error (RMSLE): 10.058
# Adj R Square:  0.789372
# KNN_K_value =  19
# Model Name:  KNeighborsRegressor(n_neighbors=19)
# Mean Absolute Error (MAE): 16836.407
# Mean Squared Error (MSE): 544938343.718
# Root Mean Squared Error (RMSE): 23343.914
# R2_score: 0.830299
# Mean Absolute Percentage Error (MAPE): 9.789 %
# Root Mean Squared Log Error (RMSLE): 10.058
# Adj R Square:  0.789342
# KNN_K_value =  20
# Model Name:  KNeighborsRegressor(n_neighbors=20)
# Mean Absolute Error (MAE): 16998.047
# Mean Squared Error (MSE): 554137175.979
# Root Mean Squared Error (RMSE): 23540.118
# R2_score: 0.827435
# Mean Absolute Percentage Error (MAPE): 9.89 %
# Root Mean Squared Log Error (RMSLE): 10.066
# Adj R Square:  0.785787

# %%
KNN_Results
# Out:
#                              Model Name KNN K Value  Mean_Absolute_Error_MAE  \
# 0    KNeighborsRegressor(n_neighbors=1)           1                17689.398
# 1    KNeighborsRegressor(n_neighbors=2)           2                15562.853
# 2    KNeighborsRegressor(n_neighbors=3)           3                14716.791
# 3    KNeighborsRegressor(n_neighbors=4)           4                14893.617
# 4                 KNeighborsRegressor()           5                14573.070
# 5    KNeighborsRegressor(n_neighbors=6)           6                14987.323
# 6    KNeighborsRegressor(n_neighbors=7)           7                15127.345
# 7    KNeighborsRegressor(n_neighbors=8)           8                15279.078
# 8    KNeighborsRegressor(n_neighbors=9)           9                15407.455
# 9   KNeighborsRegressor(n_neighbors=10)          10                15710.534
# 10  KNeighborsRegressor(n_neighbors=11)          11                15765.444
# 11  KNeighborsRegressor(n_neighbors=12)          12                15742.914
# 12  KNeighborsRegressor(n_neighbors=13)          13                15864.173
# 13  KNeighborsRegressor(n_neighbors=14)          14                16087.714
# 14  KNeighborsRegressor(n_neighbors=15)          15                16301.763
# 15  KNeighborsRegressor(n_neighbors=16)          16                16466.947
# 16  KNeighborsRegressor(n_neighbors=17)          17                16650.276
# 17  KNeighborsRegressor(n_neighbors=18)          18                16781.416
# 18  KNeighborsRegressor(n_neighbors=19)          19                16836.407
# 19  KNeighborsRegressor(n_neighbors=20)          20                16998.047
#
#     Adj_R_Square  Root_Mean_Squared_Error_RMSE  \
# 0       0.771760                     24298.630
# 1       0.821137                     21510.280
# 2       0.843763                     20103.757
# 3       0.839399                     20382.539
# 4       0.844050                     20085.337
# 5       0.839268                     20390.891
# 6       0.835191                     20647.907
# 7       0.830302                     20951.955
# 8       0.824608                     21300.561
# 9       0.817615                     21720.981
# 10      0.816701                     21775.345
# 11      0.814971                     21877.918
# 12      0.813457                     21967.260
# 13      0.807230                     22330.880
# 14      0.801396                     22666.235
# 15      0.796275                     22956.572
# 16      0.792303                     23179.337
# 17      0.789372                     23342.302
# 18      0.789342                     23343.914
# 19      0.785787                     23540.118
#
#     Mean_Absolute_Percentage_Error_MAPE  Mean_Squared_Error_MSE  \
# 0                                10.413            5.904234e+08
# 1                                 8.966            4.626922e+08
# 2                                 8.647            4.041611e+08
# 3                                 8.702            4.154479e+08
# 4                                 8.531            4.034208e+08
# 5                                 8.726            4.157884e+08
# 6                                 8.798            4.263360e+08
# 7                                 8.881            4.389844e+08
# 8                                 8.987            4.537139e+08
# 9                                 9.161            4.718010e+08
# 10                                9.220            4.741656e+08
# 11                                9.179            4.786433e+08
# 12                                9.288            4.825605e+08
# 13                                9.389            4.986682e+08
# 14                                9.500            5.137582e+08
# 15                                9.578            5.270042e+08
# 16                                9.658            5.372817e+08
# 17                                9.752            5.448630e+08
# 18                                9.789            5.449383e+08
# 19                                9.890            5.541372e+08
#
#     Root_Mean_Squared_Log_Error_RMSLE  R2_score
# 0                              10.098  0.816135
# 1                               9.976  0.855912
# 2                               9.909  0.874139
# 3                               9.922  0.870624
# 4                               9.908  0.874370
# 5                               9.923  0.870518
# 6                               9.935  0.867234
# 7                               9.950  0.863295
# 8                               9.966  0.858708
# 9                               9.986  0.853075
# 10                              9.989  0.852339
# 11                              9.993  0.850945
# 12                              9.997  0.849725
# 13                             10.014  0.844709
# 14                             10.029  0.840009
# 15                             10.041  0.835884
# 16                             10.051  0.832684
# 17                             10.058  0.830323
# 18                             10.058  0.830299
# 19                             10.066  0.827435

# %% [markdown]
# for knn n_neighbours = 5

# %% [markdown]
# # SVM

# %%
SVMResults = pd.read_csv(r"SVMResults.csv")

# %%
# Training the SVM algorithm

from sklearn.svm import SVR

ModelSVM1 = SVR(kernel='linear', C=1.0, epsilon=0.1)
ModelSVMGaussian = SVR(kernel='rbf', C=1.0, epsilon=0.1, gamma='scale')
ModelSVMPoly = SVR(kernel='poly', degree=2, C=1.0, epsilon=0.1)
ModelSVMSig = SVR(kernel='sigmoid', C=1.0, epsilon=0.1, gamma='scale', coef0=0.0)

# Train the model
ModelSVM1.fit(x_train,y_train)
ModelSVMGaussian.fit(x_train, y_train)
ModelSVMPoly.fit(x_train, y_train)
ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set
SVMS = [ModelSVM1,ModelSVMGaussian,ModelSVMPoly,ModelSVMSig]
for model in SVMS:
    y_pred = model.predict(x_test)
    # Print the model name
    print('Model Name: ', model)
    MAE = round(metrics.mean_absolute_error(y_test, y_pred), 3)
    MSE = round(metrics.mean_squared_error(y_test, y_pred),3)
    RMSE = round (np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3)
    R2_score = round(metrics.r2_score (y_test, y_pred),6)
    MAPE = round(metrics.mean_absolute_percentage_error(y_test, y_pred)*100,3)
    RMSLE = round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3)
    Adj_R_Square = round(1 - (1-R2_score)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Mean Absolute Error (MAE):', MAE)
    print('Mean Squared Error (MSE):',MSE)
    print('Root Mean Squared Error (RMSE):', RMSE)
    print('R2_score:',R2_score)
    print('Mean Absolute Percentage Error (MAPE):',MAPE , '%')
    print('Root Mean Squared Log Error (RMSLE):',RMSLE)
    print('Adj R Square: ', Adj_R_Square)
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : model,
               'Mean_Absolute_Error_MAE' : MAE,
               'Adj_R_Square' : Adj_R_Square,
               'Root_Mean_Squared_Error_RMSE' : RMSE,
               'Mean_Absolute_Percentage_Error_MAPE' : MAPE,
               'Mean_Squared_Error_MSE' : MSE,
               'Root_Mean_Squared_Log_Error_RMSLE' : RMSLE,
               'R2_score' : R2_score,
               }
    SVMResults = SVMResults.append(new_row, ignore_index=True)
# Out:
# Model Name:  SVR(kernel='linear')
# Mean Absolute Error (MAE): 39309.963
# Mean Squared Error (MSE): 2742430905.476
# Root Mean Squared Error (RMSE): 52368.224
# R2_score: 0.145973
# Mean Absolute Percentage Error (MAPE): 22.486 %
# Root Mean Squared Log Error (RMSLE): 10.866
# Adj R Square:  -0.060144
# Model Name:  SVR()
# Mean Absolute Error (MAE): 44023.853
# Mean Squared Error (MSE): 3306057231.401
# Root Mean Squared Error (RMSE): 57498.324
# R2_score: -0.029547
# Mean Absolute Percentage Error (MAPE): 25.386 %
# Root Mean Squared Log Error (RMSLE): 10.96
# Adj R Square:  -0.278025
# Model Name:  SVR(kernel='poly')
# Mean Absolute Error (MAE): 44021.758
# Mean Squared Error (MSE): 3305069712.869
# Root Mean Squared Error (RMSE): 57489.736
# R2_score: -0.029239
# Mean Absolute Percentage Error (MAPE): 25.387 %
# Root Mean Squared Log Error (RMSLE): 10.959
# Adj R Square:  -0.277643
# Model Name:  SVR(kernel='sigmoid')
# Mean Absolute Error (MAE): 44001.627
# Mean Squared Error (MSE): 3302861843.028
# Root Mean Squared Error (RMSE): 57470.53
# R2_score: -0.028552
# Mean Absolute Percentage Error (MAPE): 25.373 %
# Root Mean Squared Log Error (RMSLE): 10.959
# Adj R Square:  -0.27679

# %%
SVMResults
# Out:
#                      Model Name  Mean_Absolute_Error_MAE  Adj_R_Square  \
# 0          SVR(kernel='linear')                39309.963     -0.060144
# 1                         SVR()                44023.853     -0.278025
# 2  SVR(degree=2, kernel='poly')                44002.312     -0.276842
# 3         SVR(kernel='sigmoid')                44001.627     -0.276790
#
#    Root_Mean_Squared_Error_RMSE  Mean_Absolute_Percentage_Error_MAPE  \
# 0                     52368.224                               22.486
# 1                     57498.324                               25.386
# 2                     57471.703                               25.373
# 3                     57470.530                               25.373
#
#    Mean_Squared_Error_MSE  Root_Mean_Squared_Log_Error_RMSLE  R2_score
# 0            2.742431e+09                             10.866  0.145973
# 1            3.306057e+09                             10.960 -0.029547
# 2            3.302997e+09                             10.959 -0.028594
# 3            3.302862e+09                             10.959 -0.028552

# %% [markdown]
# # Comparing different algorithms

# %%
RGRResults = pd.read_csv(r"RGRResults.csv")

# %%
# Build the Regression / Regressor models

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.svm import SVR

# Create objects of Regression / Regressor models with default hyper-parameters

ModelMLR = LinearRegression()
ModelDCR = DecisionTreeRegressor()
ModelRFR = RandomForestRegressor()
ModelETR = ExtraTreesRegressor()
ModelKNN = KNeighborsRegressor(n_neighbors=5)
ModelBRR = BayesianRidge()
ModelSVR = SVR(kernel='rbf', C=1.0, epsilon=0.1, gamma='scale')

# Evalution matrix for all the algorithms

MM = [ModelMLR, ModelDCR, ModelRFR, ModelETR, ModelKNN, ModelBRR, ModelSVR] 

for models in MM:
    
    # Fit the model with train data
    
    models.fit(x_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis
    MAE = round(metrics.mean_absolute_error(y_test, y_pred), 3)
    MSE = round(metrics.mean_squared_error(y_test, y_pred),3)
    RMSE = round (np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3)
    R2_score = round(metrics.r2_score (y_test, y_pred),6)
    MAPE = round(metrics.mean_absolute_percentage_error(y_test, y_pred)*100,3)
    RMSLE = round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3)
    Adj_R_Square = round(1 - (1-R2_score)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Mean Absolute Error (MAE):', MAE)
    print('Mean Squared Error (MSE):',MSE)
    print('Root Mean Squared Error (RMSE):', RMSE)
    print('R2_score:',R2_score)
    print('Mean Absolute Percentage Error (MAPE):',MAPE , '%')
    print('Root Mean Squared Log Error (RMSLE):',RMSLE)
    print('Adj R Square: ', Adj_R_Square)
    
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : round(Adj_R_Square,4),
               'Root_Mean_Squared_Error_RMSE' : RMSE,
               'Mean_Absolute_Percentage_Error_MAPE' : MAPE,
               'Mean_Squared_Error_MSE' : MSE,
               'Root_Mean_Squared_Log_Error_RMSLE': RMSLE,
               'R2_score' : round(R2_score,4)}
    RGRResults = RGRResults.append(new_row, ignore_index=True)
    #-----------------------------------------------------------------------------------------
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 12997908812048.863
# Mean Squared Error (MSE): 1.7121889151824367e+28
# Root Mean Squared Error (RMSE): 130850636803281.81
# R2_score: -5.33196756800466e+18
# Mean Absolute Percentage Error (MAPE): 6592797287.161 %
# Root Mean Squared Log Error (RMSLE): 32.505
# Adj R Square:  -6.61882222894498e+18
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 22145.635
# Mean Squared Error (MSE): 998848429.966
# Root Mean Squared Error (RMSE): 31604.563
# R2_score: 0.688946
# Mean Absolute Percentage Error (MAPE): 13.275 %
# Root Mean Squared Log Error (RMSLE): 10.361
# Adj R Square:  0.613874
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 15832.948
# Mean Squared Error (MSE): 490614992.323
# Root Mean Squared Error (RMSE): 22149.831
# R2_score: 0.847216
# Mean Absolute Percentage Error (MAPE): 9.694 %
# Root Mean Squared Log Error (RMSLE): 10.006
# Adj R Square:  0.810342
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 15470.44
# Mean Squared Error (MSE): 473214622.252
# Root Mean Squared Error (RMSE): 21753.497
# R2_score: 0.852635
# Mean Absolute Percentage Error (MAPE): 9.106 %
# Root Mean Squared Log Error (RMSLE): 9.988
# Adj R Square:  0.817069
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 14573.07
# Mean Squared Error (MSE): 403420769.448
# Root Mean Squared Error (RMSE): 20085.337
# R2_score: 0.87437
# Mean Absolute Percentage Error (MAPE): 8.531 %
# Root Mean Squared Log Error (RMSLE): 9.908
# Adj R Square:  0.84405
# Model Name:  BayesianRidge()
# Mean Absolute Error (MAE): 15858.899
# Mean Squared Error (MSE): 423525302.125
# Root Mean Squared Error (RMSE): 20579.73
# R2_score: 0.868109
# Mean Absolute Percentage Error (MAPE): 9.596 %
# Root Mean Squared Log Error (RMSLE): 9.932
# Adj R Square:  0.836277
# Model Name:  SVR()
# Mean Absolute Error (MAE): 44023.853
# Mean Squared Error (MSE): 3306057231.401
# Root Mean Squared Error (RMSE): 57498.324
# R2_score: -0.029547
# Mean Absolute Percentage Error (MAPE): 25.386 %
# Root Mean Squared Log Error (RMSLE): 10.96
# Adj R Square:  -0.278025

# %%
#step-16
#Evaluation Metrics
RGRResults
# Out:
#                                           Model Name  Mean_Absolute_Error_MAE  \
# 0                                 LinearRegression()             1.299791e+13
# 1                            DecisionTreeRegressor()             2.214564e+04
# 2  (DecisionTreeRegressor(max_features=1.0, rando...             1.583295e+04
# 3  (ExtraTreeRegressor(random_state=605809695), E...             1.547044e+04
# 4                              KNeighborsRegressor()             1.457307e+04
# 5                                    BayesianRidge()             1.585890e+04
# 6                                              SVR()             4.402385e+04
#
#    Adj_R_Square  Root_Mean_Squared_Error_RMSE  \
# 0 -6.618822e+18                  1.308506e+14
# 1  6.139000e-01                  3.160456e+04
# 2  8.103000e-01                  2.214983e+04
# 3  8.171000e-01                  2.175350e+04
# 4  8.440000e-01                  2.008534e+04
# 5  8.363000e-01                  2.057973e+04
# 6 -2.780000e-01                  5.749832e+04
#
#    Mean_Absolute_Percentage_Error_MAPE  Mean_Squared_Error_MSE  \
# 0                         6.592797e+09            1.712189e+28
# 1                         1.327500e+01            9.988484e+08
# 2                         9.694000e+00            4.906150e+08
# 3                         9.106000e+00            4.732146e+08
# 4                         8.531000e+00            4.034208e+08
# 5                         9.596000e+00            4.235253e+08
# 6                         2.538600e+01            3.306057e+09
#
#    Root_Mean_Squared_Log_Error_RMSLE      R2_score
# 0                             32.505 -5.331968e+18
# 1                             10.361  6.889000e-01
# 2                             10.006  8.472000e-01
# 3                              9.988  8.526000e-01
# 4                              9.908  8.744000e-01
# 5                              9.932  8.681000e-01
# 6                             10.960 -2.950000e-02

# %% [markdown]
# # from the above KNN algorithm performs well

# %%
ModelKNN = KNeighborsRegressor(n_neighbors=5)
ModelKNN.fit(x_train,y_train)
y_pred = ModelKNN.predict(x_test)

# %%
# Display the Final results

Results = pd.DataFrame({ 'SalePrice_A':y_test, 'SalePrice_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal= hsdata_bk.merge (Results, left_index=True, right_index=True)

#Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1072  1073          50       RL         50.0     7585   Pave   NaN      Reg
# 408    409          60       RL        109.0    14154   Pave   NaN      Reg
# 1097  1098         120       RL          NaN     3696   Pave   NaN      Reg
# 213    214          20       RL         43.0    13568   Pave   NaN      IR2
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 54      55          80       RL         60.0     7134   Pave   NaN      Reg
# 1178  1179          50       RL         54.0     7681   Pave   NaN      IR1
# 265    266          20       RL         78.0    12090   Pave   NaN      IR1
# 404    405          60       RL          NaN    10364   Pave   NaN      IR1
# 94      95          60       RL         69.0     9337   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1072         Lvl    AllPub    Inside       Gtl      Edwards     Artery
# 408          Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 1097         Lvl    AllPub    Inside       Gtl      StoneBr       Norm
# 213          Lvl    AllPub   CulDSac       Gtl      CollgCr       Norm
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 54           Bnk    AllPub    Inside       Mod        NAmes       Norm
# 1178         Lvl    AllPub       FR2       Gtl      Crawfor       Norm
# 265          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 404          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 94           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1072       Norm     1Fam     1.5Fin            5            3       1948
# 408        Norm     1Fam     2Story            7            5       2006
# 1097       Norm   TwnhsE     1Story            8            5       1986
# 213        Norm     1Fam     1Story            5            5       1995
# 1349       Norm     1Fam     2Story            8            5       1872
# 54         Norm     1Fam       SLvl            5            5       1955
# 1178       Norm     1Fam     1.5Fin            5            6       1921
# 265        Norm     1Fam     1Story            6            6       1981
# 404        Norm     1Fam     2Story            6            5       1995
# 94         Norm     1Fam     2Story            6            5       1997
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1072          1950     Gable  CompShg     MetalSd     MetalSd       None
# 408           2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1097          1986     Gable  CompShg     HdBoard     HdBoard       None
# 213           1995     Gable  CompShg     VinylSd     VinylSd       None
# 1349          1987     Gable  CompShg     MetalSd     MetalSd       None
# 54            1955     Gable  CompShg     MetalSd     MetalSd       None
# 1178          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 265           1981     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 404           1996     Gable  CompShg     MetalSd     MetalSd       None
# 94            1997     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1072         0.0        TA        TA     CBlock       Fa       Fa
# 408        350.0        Gd        TA      PConc       Ex       Gd
# 1097         0.0        Gd        TA     CBlock       Gd       TA
# 213          0.0        TA        TA      PConc       Gd       TA
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 54           0.0        TA        TA     CBlock       TA       TA
# 1178         0.0        TA        TA     BrkTil       TA       TA
# 265        210.0        TA        Gd     CBlock       Gd       TA
# 404          0.0        TA        TA      PConc       Gd       TA
# 94           0.0        TA        Gd      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1072           Mn          Unf           0          Unf           0
# 408            No          Unf           0          Unf           0
# 1097           No          Unf           0          Unf           0
# 213            No          ALQ         716          Unf           0
# 1349           No          LwQ         259          Unf           0
# 54             No          ALQ         384          Unf           0
# 1178           No          Unf           0          Unf           0
# 265            No          GLQ         588          LwQ         228
# 404            No          Unf           0          Unf           0
# 94             No          GLQ         648          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1072        810          810    GasA        Fa          Y      FuseA
# 408        1063         1063    GasA        Ex          Y      SBrkr
# 1097       1074         1074    GasA        Ex          Y      SBrkr
# 213         274          990    GasA        Ex          Y      SBrkr
# 1349        425          684    OthW        Fa          N      SBrkr
# 54            0          384    GasA        TA          Y      SBrkr
# 1178        731          731    GasA        Ex          Y      SBrkr
# 265         606         1422    GasA        TA          Y      SBrkr
# 404         806          806    GasA        Gd          Y      SBrkr
# 94          176          824    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1072      1002       454             0       1456             1             1
# 408       1071      1101             0       2172             0             0
# 1097      1088         0             0       1088             0             0
# 213        990         0             0        990             0             1
# 1349       938      1215           205       2358             0             0
# 54        1360         0             0       1360             0             0
# 1178       820       523             0       1343             0             0
# 265       1422         0             0       1422             0             0
# 404        806       766             0       1572             0             0
# 94         905       881             0       1786             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1072         1         0             4             1          TA
# 408          2         1             3             1          Gd
# 1097         1         1             2             1          Gd
# 213          1         0             3             1          TA
# 1349         2         0             4             1          TA
# 54           1         0             3             1          TA
# 1178         1         1             3             1          TA
# 265          2         0             3             1          Gd
# 404          2         1             3             1          TA
# 94           2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1072             7        Typ           1          TA     Detchd       1954.0
# 408              9        Typ           1          Gd     Attchd       2006.0
# 1097             5        Typ           0         NaN     Attchd       1987.0
# 213              5        Typ           0         NaN     Attchd       1996.0
# 1349             8        Typ           0         NaN        NaN          NaN
# 54               6       Min1           1          TA     Detchd       1962.0
# 1178             7        Typ           1          Gd     Detchd       1921.0
# 265              7        Typ           1          TA     Attchd       1981.0
# 404              7        Typ           1          TA    BuiltIn       1995.0
# 94               7        Typ           0         NaN     Attchd       1997.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1072          Unf           1         280         TA         TA          P
# 408           RFn           3         947         TA         TA          Y
# 1097          RFn           2         461         TA         TA          Y
# 213           Unf           2         576         TA         TA          Y
# 1349          NaN           0           0        NaN        NaN          Y
# 54            Unf           2         572         TA         TA          Y
# 1178          Unf           1         186         Fa         TA          Y
# 265           Fin           2         576         TA         TA          Y
# 404           Fin           2         373         TA         TA          Y
# 94            RFn           2         684         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1072           0            0              0          0            0
# 408          192           62              0          0            0
# 1097           0           74            137          0            0
# 213          224            0              0          0            0
# 1349           0           54             20          0            0
# 54             0           50              0          0            0
# 1178         192            0            102          0            0
# 265          276            0              0          0            0
# 404            0           40              0          0            0
# 94             0          162              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1072         0    NaN    NaN         NaN        0       8    2006       WD
# 408          0    NaN    NaN         NaN        0       8    2007      New
# 1097         0    NaN    NaN         NaN        0      10    2007       WD
# 213          0    NaN    NaN         NaN        0       7    2006       WD
# 1349         0    NaN    NaN         NaN        0      12    2008       WD
# 54           0    NaN  MnPrv         NaN        0       2    2007       WD
# 1178         0    NaN    NaN         NaN        0       7    2009       WD
# 265          0    NaN  GdPrv         NaN        0       6    2008       WD
# 404          0    NaN    NaN         NaN        0       5    2007       WD
# 94           0    NaN    NaN         NaN        0       5    2007       WD
#
#      SaleCondition  SalePrice  SalePrice_A  SalePrice_P
# 1072        Normal      91500        91500     118640.0
# 408        Partial     280000       280000     293760.0
# 1097        Normal     170000       170000     186440.0
# 213         Normal     156000       156000     156000.0
# 1349        Normal     122000       122000     135600.0
# 54          Normal     130000       130000     127000.0
# 1178        Normal     154900       154900     140900.0
# 265         Normal     175500       175500     180580.0
# 404         Normal     168000       168000     174780.0
# 94          Normal     204750       204750     220100.0
